# %%
import pandas as pd

# %%
df=pd.read_csv('/home/sukanya/Desktop/hackathon/data/government-major-project-portfolio-data-september-2016.csv')

# %%
df
# Out:
#                                          Project name  \
# 0                                          Department
# 1   MPA RAG rating(A Delivery Confidence Assessmen...
# 2                 Description / Aims (From GMPP data)
# 3   Departmental commentary on actions planned or ...
# 4    Project - Start Date(Latest approved start date)
# 5        Project - End Date(Latest approved end date)
# 6   Departmental narrative on schedule, including ...
# 7                         2014/2015 Budget (�million)
# 8                       2014/2015 Forecast (�million)
# 9                       2014/2015 Variance (�million)
# 10                            2014/2015 Variance %age
# 11  Total budgeted whole life costs (�million)(inc...
# 12  Departmental narrative on  budget/forecast var...
# 13  Departmental narrative on budgeted whole life ...
#
#                               Debt Staff Reinvestment  \
# 0                                                HMRC
# ...

# %%
df.T.to_csv('government-major-project-portfolio-data-september-2016.csv',header=False, index=False)

# %%
df1.THMRC_Government_Major_Projects_Portfolio_data__September_2013__CSV_
# Out:
#                                                           0   \
# Project Name                                      Department
# CUSTOMS DECLARATION SERVICES (CDS) Programme            HMRC
# Columbus (formerly Aspire Replacement Programme)        HMRC
# Tax-Free Childcare                                      HMRC
#
#                                                                                                  1   \
# Project Name                                      IPA RAG rating(A Delivery Confidence Assessmen...
# CUSTOMS DECLARATION SERVICES (CDS) Programme                                              Amber/Red
# Columbus (formerly Aspire Replacement Programme)                                          Amber/Red
# Tax-Free Childcare                                                                            Amber
#
#                                                                                                  2   \
# ...
